# %%
import pandas as pd 
import numpy as np
from tqdm import tqdm
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Select All players that have played between 2000 to 2020

# %%
from nba_api.stats.endpoints import commonallplayers

all_players = commonallplayers.CommonAllPlayers().get_data_frames()[0]

#all_players

all_players['TO_YEAR'] = all_players['TO_YEAR'].astype('int64')

all_players = all_players[all_players['TO_YEAR']>=2000]

# %%
all_players
# Out:
#       PERSON_ID DISPLAY_LAST_COMMA_FIRST   DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 3            51      Abdul-Rauf, Mahmoud   Mahmoud Abdul-Rauf             0
# 4          1505       Abdul-Wahad, Tariq    Tariq Abdul-Wahad             0
# 5           949     Abdur-Rahim, Shareef  Shareef Abdur-Rahim             0
# 9        203518            Abrines, Alex         Alex Abrines             0
# 10      1630173        Achiuwa, Precious     Precious Achiuwa             1
# ...         ...                      ...                  ...           ...
# 4596       2583       Zimmerman, Derrick    Derrick Zimmerman             0
# 4597    1627757       Zimmerman, Stephen    Stephen Zimmerman             0
# 4598    1627835             Zipser, Paul          Paul Zipser             0
# 4599    1627790              Zizic, Ante           Ante Zizic             0
# 4602    1627826             Zubac, Ivica          Ivica Zubac             1
#
#      FROM_YEAR  TO_YEAR           PLAYERCODE     TEAM_ID TEAM_CITY TEAM_NAME  \
# 3         1990     2000   mahmoud_abdul-rauf           0
# 4         1997     2003    tariq_abdul-wahad           0
# 5         1996     2007  shareef_abdur-rahim           0
# 9         2016     2018         alex_abrines           0
# 10        2020     2020     precious_achiuwa  1610612748     Miami      Heat
# ...        ...      ...                  ...         ...       ...       ...
# 4596      2005     2005    derrick_zimmerman           0
# 4597      2016     2016    stephen_zimmerman           0
# 4598      2016     2017          paul_zipser           0
# 4599      2017     2019           ante_zizic           0
# 4602      2016     2020          ivica_zubac  1610612746        LA  Clippers
#
#      TEAM_ABBREVIATION TEAM_CODE GAMES_PLAYED_FLAG OTHERLEAGUE_EXPERIENCE_CH
# 3                                                Y                        00
# 4                                                Y                        00
# 5                                                Y                        00
# 9                                                Y                        00
# 10                 MIA      heat                 Y                        00
# ...                ...       ...               ...                       ...
# 4596                                             Y                        01
# 4597                                             Y                        01
# 4598                                             Y                        01
# 4599                                             Y                        01
# 4602               LAC  clippers                 Y                        01
#
# [2096 rows x 14 columns]

# %% [markdown]
# ## Select Players Stats from 2000 to 2020

# %%
from nba_api.stats.endpoints import playercareerstats
import time

# extract all IDs
players_ID = all_players['PERSON_ID']

# initial an empty dataframe
players_stats = pd.DataFrame()
# save fail queries
error_log = []
# extracting stats
for ID in tqdm(players_ID):
    try:
        time.sleep(1) # avoid too many queries submitted at the same time
        career = playercareerstats.PlayerCareerStats(player_id=ID)
        player_career = career.get_data_frames()[0]
        players_stats = pd.concat([players_stats,player_career],axis=0,ignore_index=True)
    except:
        error_log.append(ID)
# Out:
# 100%|██████████| 2096/2096 [1:14:47<00:00,  2.14s/it]

# %%
error_log
# Out:
# [1629109,
#  203546,
#  1721,
#  1629634,
#  236,
#  1918,
#  201961,
#  203898,
#  203516,
#  1915,
#  1629234]

# %%
for ID in tqdm(error_log):
    try:
        time.sleep(1)
        career = playercareerstats.PlayerCareerStats(player_id=ID)
        player_career = career.get_data_frames()[0]
        players_stats = pd.concat([players_stats,player_career],axis=0,ignore_index=True)
    except:
        error_log.append(ID)
# Out:
# 100%|██████████| 11/11 [00:18<00:00,  1.68s/it]

# %%
with open("player_stats.pkl",'wb') as f:
    pickle.dump(players_stats,f)

# %%
players_stats
# Out:
#       PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0            51   1990-91        00  1610612743               DEN        22.0
# 1            51   1991-92        00  1610612743               DEN        23.0
# 2            51   1992-93        00  1610612743               DEN        24.0
# 3            51   1993-94        00  1610612743               DEN        25.0
# 4            51   1994-95        00  1610612743               DEN        26.0
# ...         ...       ...       ...         ...               ...         ...
# 15085      1915   2001-02        00  1610612742               DAL        27.0
# 15086      1915   2002-03        00  1610612742               DAL        28.0
# 15087   1629234   2018-19        00  1610612759               SAS        22.0
# 15088   1629234   2019-20        00  1610612759               SAS        23.0
# 15089   1629234   2020-21        00  1610612759               SAS        24.0
#
#        GP  GS     MIN  FGM  ... FT_PCT  OREB DREB  REB  AST STL BLK  TOV   PF  \
# 0      67  19  1505.0  417  ...  0.857    34   87  121  206  55   4  110  149
# 1      81  11  1538.0  356  ...  0.870    22   92  114  192  44   4  117  130
# 2      81  81  2710.0  633  ...  0.935    51  174  225  344  84   8  187  179
# 3      80  78  2617.0  588  ...  0.956    27  141  168  362  82  10  151  150
# 4      73  43  2082.0  472  ...  0.885    32  105  137  263  77   9  119  126
# ...    ..  ..     ...  ...  ...    ...   ...  ...  ...  ...  ..  ..  ...  ...
# 15085  31   6   299.0   21  ...  0.606    35   63   98    9  10   9   16   60
# 15086  17   3   135.0    7  ...  0.750    10   19   29    6  10   7    6   35
# 15087  23   0   113.0   15  ...  0.846     6   28   34    7   2   5    8   11
# 15088  22   3   272.0   43  ...  0.769    28   57   85   15   5  17   21   37
# 15089  54   3   755.0  116  ...  0.726    74  167  241   42  18  49   45   88
#
#         PTS
# 0       942
# 1       837
# 2      1553
# 3      1437
# 4      1165
# ...     ...
# 15085    62
# 15086    17
# 15087    41
# 15088   107
# 15089   311
#
# [15090 rows x 27 columns]

# %%
players_stats[players_stats.TEAM_ID==1610612761]
# Out:
#       PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 41       203112   2012-13        00  1610612761               TOR        22.0
# 42       203112   2013-14        00  1610612761               TOR        23.0
# 53       200801   2008-09        00  1610612761               TOR        25.0
# 103      201582   2010-11        00  1610612761               TOR        23.0
# 111      202374   2010-11        00  1610612761               TOR        23.0
# ...         ...       ...       ...         ...               ...         ...
# 14851   1626153   2017-18        00  1610612761               TOR        26.0
# 14852   1626153   2018-19        00  1610612761               TOR        27.0
# 14873    201153   2010-11        00  1610612761               TOR        24.0
# 15017      1721   2000-01        00  1610612761               TOR        26.0
# 15019      1721   2001-02        00  1610612761               TOR        27.0
#
#        GP  GS     MIN  FGM  ... FT_PCT  OREB DREB  REB  AST STL  BLK  TOV  \
# 41     29   0   342.0   42  ...  0.816    30   47   77   11  13   15   17
# 42      7   0    61.0    6  ...  0.625     5   10   15    4   4    3    2
# 53     12   0    52.0    4  ...  0.500     1    6    7    1   1    1    4
# 103    24   0   265.0   47  ...  0.733    12   49   61    8   8   14   17
# 111    12   0    59.0    3  ...  0.000     7    7   14    2   2    2    3
# ...    ..  ..     ...  ...  ...    ...   ...  ...  ...  ...  ..  ...  ...
# 14851  69   4  1433.0  201  ...  0.829    45  153  198  200  72   33   78
# 14852  49   2   897.0  127  ...  0.869    39   86  125  110  46   15   37
# 14873  52   6   766.0   82  ...  0.512    47   71  118   58  39   20   43
# 15017  46   0   969.0  167  ...  0.585    78  170  248   38  16  110   42
# 15019  81  31  2187.0  380  ...  0.674   182  421  603   88  58  122  140
#
#         PF  PTS
# 41      53  116
# 42       8   19
# 53       4   11
# 103     60  114
# 111      5    6
# ...    ...  ...
# 14851   81  555
# 14852   53  337
# 14873   45  188
# 15017  143  413
# 15019  258  915
#
# [446 rows x 27 columns]

# %% [markdown]
# ## Get Team data

# %%
from nba_api.stats.endpoints import teamyearbyyearstats
from nba_api.stats.static import teams

# %%
nba_teams = teams.get_teams()

# %%
teams_stats = pd.DataFrame()
error_teams =[]
for i in tqdm(nba_teams):
    try:
        time.sleep(1)
        team = teamyearbyyearstats.TeamYearByYearStats(team_id=i['id'])
        team_data = team.get_data_frames()[0]
        teams_stats = pd.concat([teams_stats,team_data],axis=0,ignore_index=True)
    except:
        error_teams.append(i)
# Out:
# 100%|██████████| 30/30 [00:47<00:00,  1.58s/it]

# %%
teams_stats
# Out:
#          TEAM_ID   TEAM_CITY   TEAM_NAME     YEAR  GP  WINS  LOSSES  WIN_PCT  \
# 0     1610612737  Tri-Cities  Blackhawks  1949-50  64    29      35    0.453
# 1     1610612737  Tri-Cities  Blackhawks  1950-51  68    25      43    0.368
# 2     1610612737   Milwaukee       Hawks  1951-52  66    17      49    0.258
# 3     1610612737   Milwaukee       Hawks  1952-53  71    27      44    0.380
# 4     1610612737   Milwaukee       Hawks  1953-54  72    21      51    0.292
# ...          ...         ...         ...      ...  ..   ...     ...      ...
# 1532  1610612766   Charlotte     Hornets  2016-17  82    36      46    0.439
# 1533  1610612766   Charlotte     Hornets  2017-18  82    36      46    0.439
# 1534  1610612766   Charlotte     Hornets  2018-19  82    39      43    0.476
# 1535  1610612766   Charlotte     Hornets  2019-20  65    23      42    0.354
# 1536  1610612766   Charlotte     Hornets  2020-21  72    33      39    0.458
#
#       CONF_RANK  DIV_RANK  ...  OREB  DREB   REB   AST    PF  STL   TOV  BLK  \
# 0             0         3  ...     0     0     0  1330  2057    0     0    0
# 1             0         5  ...     0     0     0  1476  2092    0     0    0
# 2             0         5  ...     0     0     0  1229  1848    0     0    0
# 3             0         5  ...     0     0     0  1427  2120    0     0    0
# 4             0         4  ...     0     0     0  1298  1771    0     0    0
# ...         ...       ...  ...   ...   ...   ...   ...   ...  ...   ...  ...
# 1278          6         3  ...  1098  2449  3547  1947  1989  666  1137  544
# 1279          5         2  ...  1118  2529  3647  2004  1745  599  1080  519
# 1280          7         3  ...  1114  2336  3450  1779  1771  688  1174  454
# 1281         14         7  ...  1023  2355  3378  1583  1761  609  1181  392
# 1282         10         6  ...   830  2419  3249  1574  1748  604  1164  402
# 1283         11         4  ...   844  2444  3288  1670  1876  621  1087  317
# 1284         12         4  ...   864  2291  3155  1593  1965  529  1071  272
# 1285          3         1  ...   755  2480  3235  1822  1672  581  1104  321
# 1286          6         2  ...   790  2496  3286  1953  1596  570   959  336
# 1287         13         4  ...   802  2513  3315  1835  1593  523  1098  390
# 1288          9         2  ...   806  2507  3313  1804  1819  469  1100  384
# 1289         14         5  ...   963  2343  3306  1795  1807  581  1206  350
# 1290         11         4  ...   697  2074  2771  1382  1532  429  1001  321
# 1291         10         5  ...   871  2426  3297  1765  1836  595  1124  392
# 1292          3         1  ...   935  2552  3487  1737  1882  577  1159  343
# 1293          4         1  ...   881  2526  3407  1701  1712  615  1057  357
# 1294          2         1  ...   836  2724  3560  1536  1610  636  1073  449
# 1295          3         2  ...   871  2676  3547  1517  1708  677  1041  400
# 1296          1         1  ...   800  2807  3607  1995  1783  626  1095  500
# 1297          2         1  ...   786  2920  3706  2085  1724  680  1150  437
# 1298          2         1  ...   685  2583  3268  1816  1559  636  1067  358
# 1299         12         0  ...   680  2314  2994  1735  1526  618   952  388
#
#        PTS  PTS_RANK
# 1274  7994        21
# 1275  7829        18
# 1276  7781        17
# 1277  4557        18
# 1278  7968        17
# 1279  8007         5
# 1280  7494        25
# 1281  7453        27
# 1282  7006        29
# 1283  8178         7
# 1284  8287         4
# 1285  8157        11
# 1286  8215        13
# 1287  8121        16
# 1288  8534         5
# 1289  8124        17
# 1290  5986        28
# 1291  7971        16
# 1292  8305        13
# 1293  8527         4
# 1294  8422        14
# 1295  8762        10
# 1296  9156         4
# 1297  9384         8
# 1298  8118        13
# 1299  8011        19
#
# [26 rows x 34 columns]

# %% [markdown]
# ## Awards Data

# %%
from nba_api.stats.endpoints import playerawards

# %%
players_awards = pd.DataFrame()
error_awards = []
for ID in tqdm(players_ID):
    try:
        time.sleep(1)
        award = playerawards.PlayerAwards(player_id=ID)
        award.get_data_frames()[0]
        players_awards = pd.concat([players_awards,award.get_data_frames()[0]],axis=0,ignore_index=True)
    except:
        error_awards.append(ID)
# Out:
# 100%|██████████| 2096/2096 [1:59:01<00:00,  3.41s/it]

# %%
error_awards
# Out:
# [1626164, 202344, 200767, 1916, 2430, 2414, 2547, 1934, 101236]

# %%
for ID in tqdm(error_awards):
    time.sleep(1)
    award = playerawards.PlayerAwards(player_id=ID)
    award.get_data_frames()[0]
    players_awards = pd.concat([players_awards,award.get_data_frames()[0]],axis=0,ignore_index=True)
# Out:
# 100%|██████████| 9/9 [00:11<00:00,  1.27s/it]

# %%
with open("players_awards.pkl","wb") as f:
    pickle.dump(players_awards,f)
